# %%
from main import chat_with_memory

# %%
query = """
5번하고 7번은 별로 모르겠는데? 5번 7번 제외하고 새로 7개 뽑아줘.
"""

chat_with_memory(query, thread_id='user1')
# Out:
# === 사용자(user1) 입력 ===
#
# 5번하고 7번은 별로 모르겠는데? 5번 7번 제외하고 새로 7개 뽑아줘.
#
# ================================
#
# [Step 1][Agent] 다음 도구 호출 예정: ['tool_search_patent_with_description']
# [Tool 결과 수신] tool='tool_search_patent_with_description' (내용 길이: 17875자, 미리보기: query_text='computer-implemented method for detecting one or more features of interest from a captured video or image se...)
# [Step 2][Agent 최종 답변]
# 요청하신 대로, 이전 결과 중 5번(1020220071619), 7번(1020200176154)은 제외하고 새로 상위 7건을 뽑았습니다.
# (내부 DB는 컴퓨터 비전/모빌리티 중심 서브셋이므로, 최종 선행기술 조사는 KIPRIS/특허로 등에서 별도 확인이 필요합니다.)
#
# ---
#
# ## 1. 시공간·로컬/글로벌·타임시리즈 구조와 가장 밀접한 특허들
#
# ### (1) 1020257003209 – 시공간 정보를 이용한 지능형 이미지 분석을 위한 컴퓨터 구현 시스템 및 방법
# - 개요:
#   - 영상 장치로 캡처된 이미지에서 **하나 이상의 관심 특징**을 검출하는 **컴퓨터 구현 방법/시스템**.
# - 대표 청구항 구조(요약):
#   - 캡처된 이미지로부터 **시간순으로 정렬된 이미지의 순서화된 세트** 수신
#   - **로컬 시공간 처리 모듈**:
#     - 순서화된 세트의 하나 이상의 **부분 집합을 분석**
#     - 각 부분 집합의 각 이미지에서 **관심 특징 관련 특성의 존재**를 결정
#     - 결정된 특성에 기반하여 이미지에 **주석(특징 벡터) 부여**
#   - **글로벌 시공간 처리 모듈**:
#     - 전체 특징 벡터 세트를 처리
#     - 각 이미지 부분 집합과 연관된 특성을 **정제(refine)**
#   - **시계열 분석 모듈**:
#     - 각 이미지에 대한 **수치 값** 계산
#     - 이 값은 하나 이상의 관심 특징의 존재를 나타내며,
#       정제된 특성과 시공간 정보를 이용해 계산
#   - 각 부분집합/각 이미지와 연관된 수치값으로 **관심 특징에 대한 보고서 생성**
# - 사용자 기술과의 관계:
#   - 질문에 주신 문장과 **구성·용어·문장 구조가 거의 일치**합니다.
#     사실상 동일한 발명의 다른 청구항/패밀리일 가능성이 높습니다.
#
# ---
#
# ### (2) 1020257000097 – 시공간 정보를 이용한 지능형 이미지 분석을 위한 컴퓨터 구현 시스템 및 방법
# - 개요:
#   - 동일한 “시공간 정보를 이용한 지능형 이미지 분석” 프레임워크를 다루는 시스템/방법.
# - 핵심 청구항 내용:
#   - 영상 장치로 캡처된 이미지들의 **시공간 분석** 수행
#   - 캡처 이미지로부터 **시간 순서로 정렬된 세트**에 접근
#   - **이벤트 감지기**로 시작/종료 프레임 기반 이벤트 검출
#   - **프레임 선택기**:
#     - 관련 점수(관심 특징 존재)와 품질 점수에 따라 프레임 선택
#   - **객체 기술자(objects descriptor)**:
#     - 관심 특징의 일치하는 존재에 기초하여 선택 이미지들의 **부분 집합 병합**
#     - 로컬 시공간 처리 모듈이 만든 시공간 정보 기반, **공간·시간 일관성**으로 부분집합 식별
#   - **시간 분할기(temporal segmentor)**로 시간 간격 분할
#   - 종속항에서 **로컬/글로벌 시공간 처리 모듈** 정의
# - 사용자 기술과의 관계:
#   - 질문의 “로컬/글로벌 시공간 + 관심 특징 + 시계열/시간 간 분석”과 **모듈 구성, 용어가 동일 계열**입니다.
#   - (1)과 세트로 보는 것이 좋고, 선행기술 검토 시 함께 반드시 고려되어야 할 특허로 판단됩니다.
#
# ---
#
# ### (3) 1020257000088 – 영상 분석을 위한 시공간 정보를 이용한 컴퓨터 구현 시스템 및 방법
# - 개요:
#   - **영상 세트에 대해 복수의 작업을 수행**하는 시스템/방법.
# - 대표 청구항 내용:
#   - 복수의 작업을 수신 (그 중 일부는 “영상 세트에서 하나 이상의 관심 특징을 식별”하는 요청)
#   - **로컬 시공간 처리 모듈**로 영상 세트의 하위 세트를 분석,
#     - 관심 특징과 연관된 특성의 존재를 식별
#   - 각 작업에 대해 **타임시리즈 분석 모듈 실행을 반복**,
#     - 각 작업에 대한 **수치 점수를 하위 세트의 각 영상과 연관**
# - 사용자 기술과의 관계:
#   - “로컬 시공간 모듈 + 타임시리즈 분석 모듈 + 관심 특징에 대한 수치 점수” 구조가 질문 내용과 **핵심적으로 겹칩니다**.
#   - 다만 여기서는 “복수 작업”을 받아 태스크별로 점수를 매기는 제어/스케줄링·멀티태스크 프레임워크에 더 무게가 있습니다.
#
# ---
#
# ## 2. 시공간 분석/관심 대상 검출과 관련성이 높은 특허들
#
# ### (4) 1020247004829 – 대상 검출 및 특성화를 위한 컴퓨터-구현 시스템들 및 방법들
# - 개요:
#   - **의료 영상 장치로부터 수신된 실시간 비디오 프레임**에서 관심 대상을 검출·특성화.
# - 핵심 청구항 내용:
#   - 의료 영상 디바이스에서 복수 프레임 수신
#   - 각 프레임에서 **관심 대상 검출** 및 **특징(위치, 크기 등) 결정**
#   - 대상이 여러 프레임에 걸쳐 지속될 경우,
#     - 위치·크기 정보 등을 **집계(aggregation)**하여 평가
#   - 위치/크기 조건에 따라
#     - 집계 정보를 디스플레이에 제시
#     - 또는 특성화 상태(예: 위험 여부, 진행 상태 등) 정보를 표시
#   - 일부 청구항에서, 신경망 기반 특성화·신뢰도 및 **의료 지침 도출**까지 포함
# - 사용자 기술과의 관계:
#   - 공통점: 의학 영상, 실시간 비디오, 프레임 시퀀스를 기반으로 **관심 대상/특징 검출 및 시간 축 상의 정보 집계**.
#   - 차이점: 귀하 기술은 **로컬/글로벌 시공간 모듈과 타임시리즈 분석 모듈로 수치값을 산출하고 보고/데이터파일/EMR 연동까지**를 명시하는 반면, 이 특허는 **집계된 위치·크기 정보 기반으로 의학적 피드백/디스플레이**에 초점.
#
# ---
#
# ### (5) 1020237010567 – 텍스트를 이용한 어수선한 비디오 장면들에서의 동작-물체 인식
# - 개요:
#   - **어수선한 비디오(cluttered scenes)**에서 동작-물체 상호작용을 인식하기 위한 방법.
# - 핵심 청구항 내용:
#   - 라벨이 붙은 동작-물체 비디오 수신
#   - 초기 프레임에서 관심 물체 주위 **경계 상자 계산**
#   - 후속 프레임으로 경계 상자 전파
#   - 관심 물체 지식을 활용해 경계 상자 **개량(refining)** 후 잘라내기(cropping)
#   - 잘려진 프레임 세트를 원래 순서대로 처리하여,
#     - 특정 동작이 수행될 확률을 계산
#     - 임계값 이상이면 해당 동작이 수행된다는 **확인 제공**
# - 사용자 기술과의 관계:
#   - 공통점: 비디오 프레임 시퀀스를 대상으로 특정 **관심 대상/행위**의 존재와 타임라인 상 변화를 판단.
#   - 차이점: 귀하 기술처럼 “로컬/글로벌 시공간 모듈, 시계열 분석 모듈, 수치값 기반 보고/파일 생성”의 구조는 없고, **경계 상자 전파·개량·동작 검증**에 중점.
#
# ---
#
# ### (6) 1020220105270 – 공간 인식 심층 상관 필터 학습을 통한 영상 감시 장치 및 방법
# - 개요:
#   - 영상 감시에서 **상관 필터 기반 목표 추적**을 고도화하는 기술.
# - 핵심 청구항 내용:
#   - HOG, ColorName, Intensity, ResNet-50 등 **다중 채널 특징 추출**
#   - ACS(Adaptive Channel Selection)로 적응적 채널 선택 → 제1 응답 맵
#   - **시간 정규화(temporal normalization)**로 프레임 간 관계 반영 → 제1 응답 맵 보정
#   - SCM 기반 **공간 인식 상관 필터**로 제2 응답 맵 생성
#   - 제1/2 응답 맵 결합 → 최종 응답맵 → 타겟 위치 결정
# - 사용자 기술과의 관계:
#   - 공통점: 프레임 간 관계를 고려한 **시간/공간 인식(tracking/감시) 알고리즘**.
#   - 차이점: 귀하 발명의 구조적 특징(로컬/글로벌 모듈, 타임시리즈 모듈, 수치값·보고서/데이터 생성 등)보다는 **트래킹·감시 성능 향상**에 초점.
#
# ---
#
# ### (7) 1020230163309 – 객체 인식 모델에서 신호등을 탐지하는 방법 및 그 장치
# - 개요:
#   - 카메라 영상에서 **신호등**을 안정적으로 탐지하기 위한 전자 장치.
# - 핵심 청구항 내용:
#   - 카메라로부터 입력 이미지 획득
#   - 사전 지식에 기초해 **제1 관심 영역(ROI)** 추정
#   - 과거 프레임 탐지 결과에 기반해 ROI를 **제2 관심 영역으로 업데이트**
#   - 디텍터를 이용해 입력 이미지와 제2 ROI에 기초하여 신호등 탐지
# - 사용자 기술과의 관계:
#   - 공통점: 연속 프레임(과거 프레임 정보)을 활용해 관심 영역/대상을 추적.
#   - 차이점: 귀하 기술처럼 시공간 모듈 구조를 나누고, 타임시리즈 분석으로 수치값을 출력·보고하는 프레임워크는 아니며, 특정 객체(신호등) 인식·추적에 특화.
#
# ---
#
# ## 3. 정리
#
# - 요청 조건(5번·7번 제외)에 맞춰, 현재 DB 기준 **상위 7건**은:
#   1) 1020257003209 – 시공간 정보를 이용한 지능형 이미지 분석 시스템/방법
#   2) 1020257000097 – 동일 계열 시공간 지능형 이미지 분석 시스템/방법
#   3) 1020257000088 – 시공간 정보를 이용한 영상 분석 시스템/방법 (멀티 작업 + 타임시리즈 점수)
#   4) 1020247004829 – 의료 영상에서 대상 검출·특성화·집계·표시 시스템/방법
#   5) 1020237010567 – 어수선한 비디오에서 동작-물체 인식
#   6) 1020220105270 – 공간 인식 심층 상관 필터 기반 영상 감시
#   7) 1020230163309 – 신호등 탐지용 객체 인식 장치
#
# - 이 중에서 **질문하신 구조(로컬/글로벌 시공간 모듈 + 타임시리즈 분석 + 수치값 기반 보고)**와 직접적으로 겹치는 것은
#   - 1020257003209, 1020257000097, 1020257000088
#   이 3건이 핵심 선행기술 군으로 보입니다.
#
# 필요하시면,
# - 이 세 건(3209, 0097, 0088)의 **청구항별 차이/권리범위 차이**를 더 자세히 비교해서,
# - 귀하가 구상 중인 발명의 차별화 포인트(예: 의료 EMR 통합 방식, 특정 타임시리즈 지표 정의, 모듈간 인터페이스 구조 등)를 정리해 드릴 수도 있습니다.
