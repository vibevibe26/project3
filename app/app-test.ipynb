# %%
from main import chat_with_memory

# %%
query = "레이저 총과 연결된 조끼를 입고 그 조끼에서 레이저를 인식하는 센서가 있는거야. 그래서 다른 사람의 레이저에 맞으면 연결된 센서가 인식해서 착용자의 hp를 깎고 그 관련해서 외부 디스플레이 모니터에 표시되는거지. 이거랑 유사한 특허가 있나 알아봐주고 ipc코드도 알아봐줘"
chat_with_memory(query,thread_id='user2')
# Out:
# --- 사용자(user2): 레이저 총과 연결된 조끼를 입고 그 조끼에서 레이저를 인식하는 센서가 있는거야. 그래서 다른 사람의 레이저에 맞으면 연결된 센서가 인식해서 착용자의 hp를 깎고 그 관련해서 외부 디스플레이 모니터에 표시되는거지. 이거랑 유사한 특허가 있나 알아봐주고 ipc코드도 알아봐줘 ---
# [Agent 생각]: 'tool_search_patent_with_description' 도구를 사용해야겠다...
# [Tool 결과]: 데이터 수신 완료 (4361 글자)
# [Tool 결과]: 데이터 수신 완료 (2637 글자)
# [Agent 답변]: 말씀하신 시스템(레이저 총 + 센서 조끼 + HP 관리 + 외부 모니터 표시)은 전형적인 “레이저 태그(Laser Tag) 게임 시스템” 구조에 가깝고, 유사한 컨셉의 특허는 국내·외에 상당히 많이 존재합니다.
#
# 아래에서
# 1) 이 아이디어와 가까운 특허 유형을 요약하고,
# 2) 관련 IPC 코드(국제특허분류)를 “섹션 → 클래스 → 그룹” 구조로 정리해 드리겠습니다.
#
# ※ 도구로 검색한 특허 결과는 대부분 “라이트필드/비디오 게임 디스플레이 시스템” 쪽이어서, 지금 아이디어와 1:1로 같은 청구항은 아니지만, “게임 컨텐츠를 중앙 서버에서 관리하고 디스플레이하는 시스템”과의 유사성이 있습니다.
# 레이저 태그 자체는 오래된 분야라, 핵심 개념은 이미 공지되었을 가능성이 매우 높습니다.
#
# ---
#
# ## 1. 아이디어 기술 포인트 정리
#
# 사용자 아이디어를 특허 관점에서 나누면 대략 다음과 같이 정리됩니다.
#
# 1) 레이저/IR 총
# - 사용자가 손에 쥐는 “총”에서 레이저 또는 적외선 신호를 발사
#
# 2) 센서 조끼(피격 인식)
# - 착용자의 상반신에 착용하는 조끼
# - 조끼 곳곳에 적외선/레이저 수신 센서가 배치
# - 다른 사람의 총에서 발사된 신호를 맞으면 “피격”으로 인식
#
# 3) HP(Health Point) 관리 로직
# ...
